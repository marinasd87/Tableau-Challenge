# %%
import pandas as pd

# %%
citibike202101 = pd.read_csv("/Users/marinaduarte/Documents/Tableu HW/202101-citibike-tripdata.csv")
citibike202101.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          2513  2021-01-01 00:00:11.9020  2021-01-01 00:42:05.2260
# 1          2519  2021-01-01 00:00:15.0960  2021-01-01 00:42:14.9780
# 2          1207  2021-01-01 00:00:28.9300  2021-01-01 00:20:36.6510
# 3          2506  2021-01-01 00:00:32.7130  2021-01-01 00:42:19.3980
# 4           959  2021-01-01 00:00:35.3650  2021-01-01 00:16:34.6010
#
#    start station id          start station name  start station latitude  \
# 0              3581  Underhill Ave & Lincoln Pl               40.674012
# 1              3581  Underhill Ave & Lincoln Pl               40.674012
# 2              3144          E 81 St & Park Ave               40.776777
# 3              3581  Underhill Ave & Lincoln Pl               40.674012
# 4               534     Water - Whitehall Plaza               40.702551
#
#    start station longitude  end station id            end station name  \
# ...

# %%
citibike202012 = pd.read_csv("/Users/marinaduarte/Documents/Tableu HW/202012-citibike-tripdata.csv")
citibike202011 = pd.read_csv("/Users/marinaduarte/Documents/Tableu HW/202011-citibike-tripdata.csv")
citibike202010 = pd.read_csv("/Users/marinaduarte/Documents/Tableu HW/202010-citibike-tripdata.csv")
citibike202009 = pd.read_csv("/Users/marinaduarte/Documents/Tableu HW/202009-citibike-tripdata.csv")
citibike202008 = pd.read_csv("/Users/marinaduarte/Documents/Tableu HW/202008-citibike-tripdata.csv")
citibike202007 = pd.read_csv("/Users/marinaduarte/Documents/Tableu HW/202007-citibike-tripdata.csv")
citibike202006 = pd.read_csv("/Users/marinaduarte/Documents/Tableu HW/202006-citibike-tripdata.csv")
citibike202005 = pd.read_csv("/Users/marinaduarte/Documents/Tableu HW/202005-citibike-tripdata.csv")
citibike202004 = pd.read_csv("/Users/marinaduarte/Documents/Tableu HW/202004-citibike-tripdata.csv")
citibike202003 = pd.read_csv("/Users/marinaduarte/Documents/Tableu HW/202003-citibike-tripdata.csv")
citibike202002 = pd.read_csv("/Users/marinaduarte/Documents/Tableu HW/202002-citibike-tripdata.csv")

# %%
frames = [citibike202010, citibike202009, citibike202008, citibike202007, citibike202006, citibike202005, citibike202004, citibike202003]

# %%
final = pd.concat(frames)
final
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                1403  2020-10-01 00:00:10.7870  2020-10-01 00:23:34.5400
# 1                 462  2020-10-01 00:00:18.2390  2020-10-01 00:08:00.5710
# 2                 770  2020-10-01 00:00:21.3070  2020-10-01 00:13:12.0840
# 3                 233  2020-10-01 00:00:25.0080  2020-10-01 00:04:18.6410
# 4                 126  2020-10-01 00:00:25.3100  2020-10-01 00:02:32.1330
# ...               ...                       ...                       ...
# 1068452           137  2020-03-31 23:56:06.0490  2020-03-31 23:58:23.3880
# 1068453          1548  2020-03-31 23:57:27.6850  2020-04-01 00:23:16.4110
# 1068454           308  2020-03-31 23:58:00.2690  2020-04-01 00:03:08.9500
# 1068455           872  2020-03-31 23:58:42.9010  2020-04-01 00:13:15.5860
# 1068456           306  2020-03-31 23:59:17.2580  2020-04-01 00:04:23.8880
#
#          start station id        start station name  start station latitude  \
# ...

# %%
final.loc[final['gender'] == 0,'gender'] = 'unknown'
final.loc[final['gender'] == 1,'gender'] = 'male'
final.loc[final['gender'] == 2,'gender'] = 'female'
final.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1403  2020-10-01 00:00:10.7870  2020-10-01 00:23:34.5400
# 1           462  2020-10-01 00:00:18.2390  2020-10-01 00:08:00.5710
# 2           770  2020-10-01 00:00:21.3070  2020-10-01 00:13:12.0840
# 3           233  2020-10-01 00:00:25.0080  2020-10-01 00:04:18.6410
# 4           126  2020-10-01 00:00:25.3100  2020-10-01 00:02:32.1330
#
#    start station id        start station name  start station latitude  \
# 0               224     Spruce St & Nassau St               40.711464
# 1              3161    W 76 St & Columbus Ave               40.780184
# 2               354   Emerson Pl & Myrtle Ave               40.693631
# 3              3141           1 Ave & E 68 St               40.765005
# 4               335  Washington Pl & Broadway               40.729039
#
#    start station longitude  end station id           end station name  \
# ...

# %%
final.to_csv("/Users/marinaduarte/Documents/Tableu HW/final.csv")
